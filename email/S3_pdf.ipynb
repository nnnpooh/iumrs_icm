# %%
import pandas as pd
import os
from docx2pdf import convert

# %%
for file in os.listdir("output_docx"):
    if file.endswith(".docx"):
        convert(os.path.join("output_docx", file), os.path.join("output_pdf", file.replace(".docx", ".pdf")))
